# %%
import pandas as pd
import xarray as xr
import numpy as np
import copy
import math
import random
import warnings
import matplotlib.pyplot as plt
import os
from deap import base
from deap import creator
from deap import tools
import calliope
from calliope.exceptions import ModelWarning

calliope.set_log_verbosity(verbosity='INFO', include_solver_output=True, capture_warnings=True)
#warnings.filterwarnings("ignore", category=ModelWarning)

# %%
model = calliope.Model('Model/model.yaml', scenario='2050_eff,no_old_techs')
# Out:
# [2025-01-16 17:33:03] INFO     Model: initialising
# [2025-01-16 17:33:03] INFO     Applying the following overrides from scenario definition: ['2050_eff', 'no_old_techs']
# [2025-01-16 17:33:04] INFO     Override applied to locations.CNOR.techs.demand_power.constraints.resource: file=regional_demand.csv -> file=demand_2050_eff.csv
# Override applied to locations.CSUD.techs.demand_power.constraints.resource: file=regional_demand.csv -> file=demand_2050_eff.csv
# Override applied to locations.NORD.techs.demand_power.constraints.resource: file=regional_demand.csv -> file=demand_2050_eff.csv
# Override applied to locations.SARD.techs.demand_power.constraints.resource: file=regional_demand.csv -> file=demand_2050_eff.csv
# Override applied to locations.SICI.techs.demand_power.constraints.resource: file=regional_demand.csv -> file=demand_2050_eff.csv
# Override applied to locations.SUD.techs.demand_power.constraints.resource: file=regional_demand.csv -> file=demand_2050_eff.csv
# `techs.ccgt.exists`:False applied from override as new configuration
# `techs.coal.exists`:False applied from override as new configuration
# `techs.coal_usc.exists`:False applied from override as new configuration
# `techs.oil_&_other.exists`:False applied from override as new configuration
# [2025-01-16 17:33:04] WARNING  c:\Users\Jacob\miniconda3\envs\calliope\lib\site-packages\calliope\exceptions.py:60: ModelWarning:
#
# Possible issues found during model processing:
#  * Model configuration specifies calliope_version=0.6.4, but you are running 0.6.10. Proceed with caution!
#  * Monetary cost class with a weight of 1 is still included in the objective. If you want to remove the monetary cost class, add `{"monetary": 0}` to the dictionary nested under  `run.objective_options.cost_class`.
#  * Unrecognised group constraint `supply_share_min` in group `vres_min_prod_share` will be ignored - possibly a misspelling?
#
#
# [2025-01-16 17:33:04] WARNING  c:\Users\Jacob\miniconda3\envs\calliope\lib\site-packages\calliope\exceptions.py:60: ModelWarning:
#
# Constraint group `vres_min_prod_share` will be completely ignored since there are no valid location::technology combinations
#
#
# [2025-01-16 17:33:04] INFO     `phs` at `R1` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2025-01-16 17:33:04] INFO     `phs` at `R13` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2025-01-16 17:33:04] INFO     `phs` at `R14` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2025-01-16 17:33:04] INFO     `phs` at `R3` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2025-01-16 17:33:04] INFO     `phs` at `R4` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2025-01-16 17:33:04] INFO     `phs` at `R5` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2025-01-16 17:33:04] INFO     `phs` at `R8` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2025-01-16 17:33:04] INFO     `phs` at `SARD` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2025-01-16 17:33:04] INFO     `phs` at `SICI` has no constraint to explicitly connect `energy_cap` to `storage_cap`, consider defining a `energy_cap_per_storage_cap_min/max/equals` constraint
# [2025-01-16 17:33:04] WARNING  c:\Users\Jacob\miniconda3\envs\calliope\lib\site-packages\calliope\exceptions.py:60: ModelWarning:
#
# Possible issues found during model processing:
#  * Tech ccgt was removed by setting ``exists: False`` - not checking the consistency of its constraints at location CNOR.
#  * Tech ccgt was removed by setting ``exists: False`` - not checking the consistency of its constraints at location CSUD.
#  * Tech ccgt was removed by setting ``exists: False`` - not checking the consistency of its constraints at location NORD.
#  * Tech ccgt was removed by setting ``exists: False`` - not checking the consistency of its constraints at location SARD.
#  * Tech ccgt was removed by setting ``exists: False`` - not checking the consistency of its constraints at location SICI.
#  * Tech ccgt was removed by setting ``exists: False`` - not checking the consistency of its constraints at location SUD.
#  * Tech coal was removed by setting ``exists: False`` - not checking the consistency of its constraints at location R10.
#  * Tech coal was removed by setting ``exists: False`` - not checking the consistency of its constraints at location R16.
#  * Tech coal was removed by setting ``exists: False`` - not checking the consistency of its constraints at location SARD.
#  * Tech coal_usc was removed by setting ``exists: False`` - not checking the consistency of its constraints at location R12.
#  * Tech oil_&_other was removed by setting ``exists: False`` - not checking the consistency of its constraints at location R18.
#  * Tech oil_&_other was removed by setting ``exists: False`` - not checking the consistency of its constraints at location R9.
#  * Tech oil_&_other was removed by setting ``exists: False`` - not checking the consistency of its constraints at location SARD.
#  * Tech oil_&_other was removed by setting ``exists: False`` - not checking the consistency of its constraints at location SICI.
#
#
# [2025-01-16 17:33:04] INFO     Model: preprocessing stage 1 (model_run)
# [2025-01-16 17:33:08] INFO     Model: preprocessing stage 2 (model_data)
# [2025-01-16 17:33:09] INFO     Model: time resampling/clustering complete
# [2025-01-16 17:33:10] INFO     Model: preprocessing complete

# %%
model.run()

df_total_cost = model.results.cost.to_series().dropna()
total_cost_optimal = df_total_cost.loc[~df_total_cost.index.map(str).str.contains('co2_emissions')].sum()

energy_cap_df = model.results.energy_cap.to_pandas()
filtered_energy_cap_df = energy_cap_df[
    ~energy_cap_df.index.str.contains("demand|transmission") &  # Exclude demand and transmission
    energy_cap_df.index.str.contains("battery|bio|hydro|phs|PV|wind")  # Include only the specified words
    energy_cap_df.index.str.contains("R1|R2|R")
]
# Out:
# [2025-01-16 17:33:10] INFO     Backend: starting model run
# [2025-01-16 17:33:10] INFO     Loading sets
# [2025-01-16 17:33:10] INFO     Loading parameters
# [2025-01-16 17:33:10] INFO     constraints are loaded in the following order: ['capacity', 'costs', 'dispatch', 'energy_balance', 'network', 'policy', 'conversion', 'conversion_plus', 'group', 'export', 'milp']
# [2025-01-16 17:33:10] INFO     creating capacity constraints
# [2025-01-16 17:33:10] INFO     creating costs constraints
# [2025-01-16 17:33:13] INFO     creating dispatch constraints
# [2025-01-16 17:33:13] INFO     creating energy_balance constraints
# [2025-01-16 17:33:13] INFO     creating network constraints
# [2025-01-16 17:33:13] INFO     creating policy constraints
# [2025-01-16 17:33:13] INFO     creating conversion constraints
# [2025-01-16 17:33:13] INFO     creating conversion_plus constraints
# [2025-01-16 17:33:13] INFO     creating group constraints
# [2025-01-16 17:33:13] INFO     creating export constraints
# [2025-01-16 17:33:13] INFO     creating milp constraints
# [2025-01-16 17:33:13] INFO     Backend: model generated. Time since start of model run: 0:00:03.750761
# [2025-01-16 17:33:13] INFO     Backend: sending model to solver
# [2025-01-16 17:33:16] DEBUG    Set parameter Username
# Academic license - for non-commercial use only - expires 2025-11-08
# [2025-01-16 17:33:16] DEBUG    Read LP format model from file C:\Users\Jacob\AppData\Local\Temp\tmpx57zaqfc.pyomo.lp
# Reading time = 0.12 seconds
# x33993: 41978 rows, 33993 columns, 93365 nonzeros
# Set parameter BarConvTol to value 0.0001
# Set parameter BarHomogeneous to value 1
# Set parameter BarIterLimit to value 3000
# Set parameter Crossover to value 0
# Set parameter FeasibilityTol to value 0.0001
# Set parameter Method to value 2
# Set parameter OptimalityTol to value 0.0001
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-8300H CPU @ 2.30GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 41978 rows, 33993 columns and 93365 nonzeros
# Model fingerprint: 0x68dbe16d
# Coefficient statistics:
#   Matrix range     [1e-04, 7e+02]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+100]
# Warning: Model contains large rhs
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Presolve removed 38622 rows and 29162 columns
# Presolve time: 0.03s
# Presolved: 3356 rows, 4831 columns, 12993 nonzeros
# Ordering time: 0.02s
#
# Barrier statistics:
#  AA' NZ     : 3.711e+04
#  Factor NZ  : 1.038e+05 (roughly 4 MB of memory)
#  Factor Ops : 3.698e+06 (less than 1 second per iteration)
#  Threads    : 4
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   1
#   33*  3.84753089e+10  3.81281184e+10  2.65e-03 1.54e-06  2.00e+00     0s
#   34   3.81874947e+10  3.80667852e+10  1.96e-01 3.49e-05  4.36e+04     0s
#   35   3.81498749e+10  3.80111246e+10  2.94e-01 2.19e-05  3.15e+04     0s
#
# Barrier solved model in 35 iterations and 0.15 seconds (0.14 work units)
# Optimal objective 3.81498749e+10
# [2025-01-16 17:33:16] INFO     Backend: solver finished running. Time since start of model run: 0:00:06.781591
# [2025-01-16 17:33:16] INFO     Backend: loaded results
# [2025-01-16 17:33:17] INFO     Backend: generated solution array. Time since start of model run: 0:00:07.251142
# [2025-01-16 17:33:17] INFO     Postprocessing: started
# [2025-01-16 17:33:17] INFO     Postprocessing: zero threshold of 1e-10 not required
# [2025-01-16 17:33:17] INFO     Postprocessing: ended. Time since start of model run: 0:00:07.389162

# %%
model_14D = model

# %%
model_FULL = model

# %%
initial_capacities_FULL = filtered_energy_cap_df.values 

# if a value is lower than 13-5, set the value to 0. This is due to everything below 1e-5 being so low it it not interesting to include
initial_capacities_FULL[initial_capacities_FULL < 1e-5] = 0

# adjust when using more models
optimal_value = total_cost_optimal # adjust when using more models

# %%
print(filtered_energy_cap_df)
# Out:
# loc_techs
# R14::biomass_wood          2500.000000
# SICI::hydro_dam           15800.000000
# SARD::hydro_ror           40000.000000
# R6::wind                      0.000000
# SARD::hydrogen_market      6928.384686
#                              ...
# R14::wind_offshore         1227.274436
# SARD::hydro_dam          183800.000000
# R8::biofuel              264300.000000
# R18::phs_new               5706.389845
# R13::phs                 579200.000000
# Length: 178, dtype: float64

# %%
updates = [
    {'tech': tech, 'loc': loc}
    for loc_tech in filtered_energy_cap_df.index
    for loc, tech in [loc_tech.split("::")]  # Split index by '::' to separate loc and tech
]

# %%
print(updates)

# %%
input_params = model.backend.access_model_inputs()

# Access energy_cap_max and energy_cap_min for each technology
energy_cap_max = input_params['energy_cap_max']
energy_cap_min = input_params['energy_cap_min']

# Convert to DataFrame for filtering
energy_cap_max_df = energy_cap_max.to_dataframe()
energy_cap_min_df = energy_cap_min.to_dataframe()

# Filter out rows with 'demand' or 'free' in the index
energy_cap_max_filtered = energy_cap_max_df[~energy_cap_max_df.index.get_level_values('loc_techs').str.contains("demand|transmission")]
energy_cap_min_filtered = energy_cap_min_df[~energy_cap_min_df.index.get_level_values('loc_techs').str.contains("demand|transmission")]


# Create a dictionary of loc_tech to [min, max] bounds meaning that you will have the loc_tech and their corresponding min max capacity
low_up_mapping = {
    loc_tech: [
        energy_cap_min_filtered.loc[loc_tech, 'energy_cap_min'],
        energy_cap_max_filtered.loc[loc_tech, 'energy_cap_max']
    ]
    for loc_tech in energy_cap_max_filtered.index
}

# Structure the updates (previously done, which are the tech:, loc: pairs) so that it can eventually be used to put in the backend
updates_order = [f"{update['loc']}::{update['tech']}" for update in updates]

# Put it in such a structure that it can be used for the mutation function. This wants it in a list order
low_up_bound = [
    low_up_mapping[loc_tech] for loc_tech in updates_order
]

max_cap_value = 1e6

# Check for 'inf' in upper bounds and adjust if needed
for i, (low, up) in enumerate(low_up_bound):
    if up == float('inf'):
        low_up_bound[i][1] = max_cap_value

# %%
print(low_up_bound)
